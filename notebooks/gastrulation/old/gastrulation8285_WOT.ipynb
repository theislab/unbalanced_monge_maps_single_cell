# %%
import os
import sys
from pathlib import Path

import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

import wot
import scanpy as sc
import scvelo as scv
import cellrank as cr
import anndata as ad
from cellrank.external.kernels import WOTKernel
from cellrank.estimators import GPCCA
#from tueplots import bundles
#from tueplots import axes

# %%
cr.logging.print_versions()
# Out:
# cellrank==1.5.1+g525b847 scanpy==1.9.1 anndata==0.8.0 numpy==1.23.5 numba==0.56.4 scipy==1.10.0 pandas==1.5.2 pygpcca==1.0.4 scikit-learn==1.2.0 statsmodels==0.13.5 scvelo==0.2.5 pygam==0.8.0 matplotlib==3.6.2 seaborn==0.12.2

# %%
adata825 = sc.read("/lustre/groups/ml01/workspace/monge_velo/data/benchmarks/gastrulation/stage_825_growth_rate.h5ad")
adata85 = sc.read("/lustre/groups/ml01/workspace/monge_velo/data/benchmarks/gastrulation/stage_85_growth_rate.h5ad")
adata = ad.concat([adata825, adata85], merge = 'same')

adata.obs = adata.obs.loc[:, ['stage', 'celltype']]
adata.var = adata.var.loc[:, ['highly_variable']]
adata.obs['celltype'] = pd.Series(adata.obs['celltype'], dtype='category')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 31403 × 53801
#     obs: 'stage', 'celltype'
#     var: 'highly_variable'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'spliced', 'unspliced'

# %%
wk = WOTKernel(adata, time_key="stage")
wk.compute_initial_growth_rates(organism="mouse", key_added="growth_rate_init")
wk.compute_transition_matrix(
    growth_iters=3, growth_rate_key="growth_rate_init"
)
# Out:
# WARNING: genes are not in var_names and ignored: ['Mlf1ip', 'Fam64a']
# WARNING: genes are not in var_names and ignored: ['Adck3', 'Gnb2l1']
#   0%|                                                                                      | 0/1 [00:46<?, ?time pair/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 wk = WOTKernel(adata, time_key="stage")
#       2 wk.compute_initial_growth_rates(organism="mouse", key_added="growth_rate_init")
# ----> 3 wk.compute_transition_matrix(
#       4     growth_iters=3, growth_rate_key="growth_rate_init"
#       5 )
#
# File ~/miniconda3/envs/neuralBenchmark_moscot/lib/python3.9/site-packages/cellrank/external/kernels/_wot_kernel.py:329, in WOTKernel.compute_transition_matrix(self, cost_matrices, lambda1, lambda2, epsilon, growth_iters, solver, growth_rate_key, use_highly_variable, threshold, self_transitions, conn_weight, conn_kwargs, **kwargs)
#     326 _ = kwargs.pop("ncells", None)
#     327 _ = kwargs.pop("parameters", None)  # parameters file
# --> 329 _ = super().compute_transition_matrix(
#     330     threshold=threshold,
#     331     self_transitions=self_transitions,
#     332     conn_weight=conn_weight,
#     333     conn_kwargs=conn_kwargs,
#     334     cost_matrices=cost_matrices,
#     335     lambda1=lambda1,
#     336     lambda2=lambda2,
#     337     epsilon=epsilon,
#     338     growth_iters=max(growth_iters, 1),
#     339     solver=solver,
#     340     growth_rate_key=growth_rate_key,
#     341     **kwargs,
#     342 )
#     343 self.adata.obs["estimated_growth_rates"] = self.growth_rates[f"g{growth_iters}"]
#     345 return self
#
# File ~/miniconda3/envs/neuralBenchmark_moscot/lib/python3.9/site-packages/cellrank/kernels/_transport_map_kernel.py:212, in TransportMapKernel.compute_transition_matrix(self, threshold, self_transitions, conn_weight, conn_kwargs, **kwargs)
#     210 self._tmaps = {}
#     211 for t1, t2 in tqdm(timepoints, unit="time pair"):
# --> 212     tmat = self._compute_tmap(t1, t2, **kwargs)
#     213     self.transport_maps[t1, t2] = self._tmat_to_adata(t1, t2, tmat)
#     215 if threshold is not None:
#
# File ~/miniconda3/envs/neuralBenchmark_moscot/lib/python3.9/site-packages/cellrank/external/kernels/_wot_kernel.py:360, in WOTKernel._compute_tmap(self, t1, t2, cost_matrices, use_highly_variable, **kwargs)
#     356 ot_model = self._create_ot_model(adata, **kwargs)
#     357 cost_matrix = self._compute_cost_matrix(
#     358     t1, t2, adata, cost_matrices=cost_matrices
#     359 )
# --> 360 tmap: Optional[AnnData] = ot_model.compute_transport_map(
#     361     t1,
#     362     t2,
#     363     cost_matrix=cost_matrix,
#     364 )
#     365 if tmap is None:
#     366     raise TypeError(
#     367         f"Unable to compute transport map for time pair `{(t1, t2)}`. "
#     368         f"Please ensure that `adata.obs[{self._time_key!r}]` has the correct dtype (float)."
#     369     )
#
# File ~/miniconda3/envs/neuralBenchmark_moscot/lib/python3.9/site-packages/wot/ot/ot_model.py:240, in OTModel.compute_transport_map(self, t0, t1, covariate, cost_matrix)
#     237     logger.info('Computing transport map from {} {} to {} {}'.format(t0, covariate[0], t1, covariate[1]))
#     238 config = {**self.ot_config, **local_config, 't0': t0, 't1': t1, 'covariate': covariate,
#     239           'C': cost_matrix}
# --> 240 return self.compute_single_transport_map(config)
#
# File ~/miniconda3/envs/neuralBenchmark_moscot/lib/python3.9/site-packages/wot/ot/ot_model.py:318, in OTModel.compute_single_transport_map(self, config)
#     316 else:
#     317     config['G'] = np.ones(C.shape[0])
# --> 318 tmap, learned_growth = wot.ot.compute_transport_matrix(solver=self.solver, **config)
#     319 learned_growth.append(tmap.sum(axis=1))
#     320 obs_growth = {}
#
# File ~/miniconda3/envs/neuralBenchmark_moscot/lib/python3.9/site-packages/wot/ot/optimal_transport.py:30, in compute_transport_matrix(solver, **params)
#      28     params['G'] = row_sums
#      29     learned_growth.append(row_sums)
# ---> 30     tmap = solver(**params)
#      31     gc.collect()
#      33 return tmap, learned_growth
#
# File ~/miniconda3/envs/neuralBenchmark_moscot/lib/python3.9/site-packages/wot/ot/optimal_transport.py:134, in optimal_transport_duality_gap(C, G, lambda1, lambda2, epsilon, batch_size, tolerance, tau, epsilon0, max_iter, **ignored)
#     132 old_a, old_b = a, b
#     133 a = (p / (K.dot(np.multiply(b, dy)))) ** alpha1 * np.exp(-u / (lambda1 + epsilon_i))
# --> 134 b = (q / (K.T.dot(np.multiply(a, dx)))) ** alpha2 * np.exp(-v / (lambda2 + epsilon_i))
#     136 # stabilization
#     137 if (max(max(abs(a)), max(abs(b))) > tau):
#
# KeyboardInterrupt:

# %%
g = GPCCA(wk)

# %%
g.compute_schur(n_components=20)
g.plot_spectrum(real_only=True)

# %%
g.compute_macrostates(n_states=10, cluster_key="celltype")
scv.set_figure_params('scvelo', transparent=True, fontsize=20, color_map='viridis')
g.plot_macrostates(discrete=True, basis="umap", legend_loc="right", legend_fontweight='normal', legend_fontsize='12', dpi=250)
# Out:
# /home/icb/jonas.flor/miniconda3/envs/neuralBenchmark_moscot/lib/python3.9/site-packages/scvelo/plotting/scatter.py:614: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   smp = ax.scatter(

# %%
g.compute_macrostates(n_states=9, cluster_key="celltype")
scv.set_figure_params('scvelo', transparent=True, fontsize=20, color_map='viridis')
g.plot_macrostates(discrete=True, basis="umap", legend_loc="right", legend_fontweight='normal', legend_fontsize='12', dpi=250)

# %%
g.set_terminal_states_from_macrostates(
    [
        "Acinar_1", "Acinar_2", "Ductal_1", "Ductal_2", "Alpha", "Beta", "Delta", "Epsilon",  #celltypes pancreas, CHANGE!
    ]
)
g.compute_absorption_probabilities(solver="gmres", use_petsc=True, tol=1e-12, preconditioner='ilu', time_to_absorption='all')
g.plot_absorption_probabilities(same_plot=False, basis="umap", perc=[0, 99], ncols=2)

# %%
cr.pl.aggregate_absorption_probabilities(
    adata,
    mode='heatmap',
    lineages=["Acinar_1", "Acinar_2", "Ductal_1", "Ductal_2", "Alpha", "Beta", "Delta", "Epsilon"],
    cluster_key='celltype',
    clusters=['Acinar', 'Multipotent', 'Tip', 'Ductal', 'Ngn3 High early', 'Ngn3 High late', 'Fev+ Alpha', 'Alpha', 'Fev+ Beta', 'Beta', 'Fev+ Delta', 'Delta', 'Fev+ Epsilon', 'Epsilon'],
    figsize=(17, 7),
    title="",
    #save="transprobs_wot.png"
)
