# %%
import matplotlib.pyplot as plt
import anndata as ad
import scanpy as sc

# %%
data_larry_monge = ad.read("/home/icb/jonas.flor/precomputed_data/larry_monge_whole.h5ad").obs.copy()
data_larry_scvelo = ad.read("/home/icb/jonas.flor/precomputed_data/larry_scvelo_whole.h5ad")

data_gast_branch_monge = ad.read("/home/icb/jonas.flor/precomputed_data/gast_branch_monge_whole.h5ad").obs.copy()
data_gast_branch_scvelo = ad.read("/home/icb/jonas.flor/precomputed_data/gast_branch_scvelo_whole.h5ad")

# %%
data_gast_branch_scvelo.obs["velo_conf_monge"] = data_gast_branch_monge["velocity_confidence"]
data_larry_scvelo.obs["velo_conf_monge"] = data_larry_monge["velocity_confidence"]

# %%
sc.pl.violin(data_gast_branch_scvelo, keys=['velocity_confidence', 'velo_conf_monge'], palette=['green', 'brown'])

# %%
sc.pl.violin(data_larry_scvelo, keys=['velocity_confidence', 'velo_conf_monge'], palette=['green', 'brown'])

# %%
pancreas = {'redundancy': [0, 2, 1], 'transition': [0.754, 0.652, 0.934]}
gastrulation = {'redundancy': [0, 0, 2], 'transition': [0.053, 1, 1]}
larry = {'redundancy': [5, 3, 4], 'transition': [0.211, 0.259, 0.176]}

# %%
plt.barh(['MongeVelo', 'Waddington OT', 'scVelo'],pancreas['redundancy'], color=['brown', 'blue', 'green'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(['scVelo', 'Waddington OT', 'MongeVelo'], pancreas['transition'], color=['green', 'blue', 'brown'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh(['MongeVelo', 'Waddington OT', 'scVelo'], gastrulation['redundancy'], color=['brown', 'blue', 'green'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(['scVelo', 'Waddington OT', 'MongeVelo'], gastrulation['transition'], color=['green', 'blue', 'brown'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh(['MongeVelo', 'Waddington OT', 'scVelo'], larry['redundancy'], color=['brown', 'blue', 'green'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(['scVelo', 'Waddington OT', 'MongeVelo'], larry['transition'], color=['green', 'blue', 'brown'])
# Out:
# <BarContainer object of 3 artists>
